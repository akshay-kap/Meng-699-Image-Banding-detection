# %% [markdown]
# # Loading the libraries

# %%
import numpy as np
import pandas as pd

# %%
import pickle

with open('y_test_banded.pickle', 'rb') as f:
    y_test_banded = pickle.load(f)
f.close()

with open('y_test_non_banded.pickle', 'rb') as f:
    y_test_non_banded = pickle.load(f)
f.close()


print("shape for y_test_banded",y_test_banded.shape)

print("shape for y_test_non_banded",y_test_non_banded.shape)
# Out:
# shape for y_test_banded (7476, 1)
# shape for y_test_non_banded (9564, 1)

# %%
y_test_non_banded.shape
# Out:
# (9564, 1)

# %% [markdown]
# ## resversing predictions for making banding as positive result

# %%
y_test_banded1 = 1 - y_test_banded

# %%
y_test_non_banded1 = 1 - y_test_non_banded

# %%
y_test_banded1
# Out:
# array([[0.9966008 ],
#        [0.9985055 ],
#        [0.9990041 ],
#        ...,
#        [0.9552649 ],
#        [0.99997306],
#        [0.9859717 ]], dtype=float32)

# %%
y_test_non_banded1
# Out:
# array([[0.00554723],
#        [0.05547214],
#        [0.07592112],
#        ...,
#        [0.00700599],
#        [0.22521937],
#        [0.01014459]], dtype=float32)

# %% [markdown]
# ## writing y=1 for banded and y = 0 for non banded

# %%
y_test_banded_actual = np.ones((y_test_banded1.shape[0],1))

# %%
y_test_non_banded_actual = np.zeros((y_test_non_banded1.shape[0],1))

# %% [markdown]
# ## concatinating banded and non banded results

# %%
Y_test_pred = np.concatenate((y_test_banded1,y_test_non_banded1),axis=0)

# %%
Y_test_actual = np.concatenate((y_test_banded_actual,y_test_non_banded_actual),axis=0)

# %%
Y_test_pred.shape
# Out:
# (17040, 1)

# %%
Y_test_actual.shape
# Out:
# (17040, 1)

# %% [markdown]
# ## Lets try ROC curve from Sklearn

# %%
from sklearn import metrics

# %%
fpr_test, tpr_test, thresholds_test = metrics.roc_curve(Y_test_actual, Y_test_pred)

# %%
auc = metrics.roc_auc_score(Y_test_actual,Y_test_pred)
print('AUC: %.3f' % auc)
# Out:
# AUC: 0.964

# %%
import matplotlib.pyplot as plt
plt.plot(fpr_test, tpr_test)
plt.xlabel("Specificity: 1-FPR ")
plt.ylabel("Sensitivity : TPR ")
plt.title("ROC curve for model performance")
# Out:
# Text(0.5, 1.0, 'ROC curve for model performance')

# %% [markdown]
# ## Plotting Precision Recall Curve

# %%
precision,recall,threshold = metrics.precision_recall_curve(Y_test_actual, Y_test_pred)

# %%
f1_score = []
for i in range(len(precision)):
    prec = precision[i]
    recl = recall[i]
    f1_temp = 2*prec*recl/(prec+recl)
    f1_score.append(f1_temp)

# %%
import matplotlib.pyplot as plt
plt.plot(threshold,precision[:-1],label = "Precision")
plt.plot(threshold,recall[:-1], label = "Recall")
plt.plot(threshold,f1_score[:-1], label = "F1-Score")
plt.ylabel("Sensitivity : TPR ")
plt.title("ROC curve for model performance")
plt.legend()

# %% [markdown]
# # Finding the optimal values of threshold

# %%
for i in range(len(precision)):
    prec = precision[i]
    recl = recall[i]
    if (prec == recl):
        print(threshold[i])
        break
# Out:
# 0.20915085

# %% [markdown]
# ## Lets make a function that returns TPs FPs and all for a given number of examples

# %%
def tell_me_the_matrix (a1, a2, threshold):
    actual = a1
    pred = a2
    num_samples = actual.shape[0]
    temp = np.zeros((num_samples,1))

    for i in range(num_samples):
        if(pred[i,:]>=threshold):
            temp[i,:]=1
        else :
            temp[i,:]=0
            
    print(temp-a2)
            
    #TP
    TP = 0
    #print(threshold)
    for i in range(num_samples):
        if (temp[i,:]==1) and (actual[i,:]==1):
            TP+=1
    print("True positives are ", TP)
    
    #FP
    FP = 0 
    for i in range(num_samples):
        if (temp[i,:]==1) and (actual[i,:]==0):
            FP+=1
    print("False positives are ", FP)
        
    #TN
    TN = 0 
    for i in range(num_samples):
        if (temp[i,:]==0) and (actual[i,:]==0):
            TN+=1
    print("True Negatives are ", TN)    
    
    #FN
    FN = 0 
    for i in range(num_samples):
        if (temp[i,:]==0) and (actual[i,:]==1):
            FN+=1
    print("False Negatives are ", FN)      
    
    return [TP,FP,TN,FN]

# %%
import pandas as pd

# %%
accuracy =[]
TP = []
FP = []
TN = []
FN = []
TPR = []
FPR = []
Precision = []
Recall = []
F1_score = []
list_t = [0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.50,0.55,0.6,0.65,0.7,0.75,0.8,0.81,0.82,0.83,0.84,0.85,0.86,0.87,0.88,0.89,0.90,0.91,0.92,0.93,0.94,0.95,0.96,0.97,0.98,0.99]
for i in list_t:
    a = tell_me_the_matrix(Y_test_actual, Y_test_pred,i)
    total = a[0]+a[1]+a[2]+a[3]
    TP.append(a[0]*100/total)
    FP.append(a[1]*100/total)
    TN.append(a[2]*100/total)
    FN.append(a[3]*100/total)
    Precision.append(a[0]/(a[0]+a[1]))
    Recall.append(a[0]/(a[0]+a[3]))
    accuracy.append((a[0]+a[2])/total)
    TPR.append(a[0]/(a[0]+a[3]))
    FPR.append(a[1]/(a[1]+a[2]))
    pr = a[0]/(a[0]+a[1])
    re = a[0]/(a[0]+a[3])
    F1_score.append(2*pr*re/(pr+re))
# Out:
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [ 0.77478063]
#  [-0.01014459]]
# True positives are  7161
# False positives are  2048
# True Negatives are  7516
# False Negatives are  315
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [ 0.77478063]
#  [-0.01014459]]
# True positives are  6998
# False positives are  1315
# True Negatives are  8249
# False Negatives are  478
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [ 0.77478063]
#  [-0.01014459]]
# True positives are  6878
# False positives are  953
# True Negatives are  8611
# False Negatives are  598
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [ 0.77478063]
#  [-0.01014459]]
# True positives are  6748
# False positives are  784
# True Negatives are  8780
# False Negatives are  728
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  6628
# False positives are  664
# True Negatives are  8900
# False Negatives are  848
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  6518
# False positives are  576
# True Negatives are  8988
# False Negatives are  958
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  6409
# False positives are  497
# True Negatives are  9067
# False Negatives are  1067
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  6306
# False positives are  429
# True Negatives are  9135
# False Negatives are  1170
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  6194
# False positives are  371
# True Negatives are  9193
# False Negatives are  1282
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  6097
# False positives are  332
# True Negatives are  9232
# False Negatives are  1379
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5991
# False positives are  296
# True Negatives are  9268
# False Negatives are  1485
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5868
# False positives are  253
# True Negatives are  9311
# False Negatives are  1608
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5721
# False positives are  218
# True Negatives are  9346
# False Negatives are  1755
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5587
# False positives are  190
# True Negatives are  9374
# False Negatives are  1889
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5406
# False positives are  159
# True Negatives are  9405
# False Negatives are  2070
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5210
# False positives are  113
# True Negatives are  9451
# False Negatives are  2266
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5164
# False positives are  107
# True Negatives are  9457
# False Negatives are  2312
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5119
# False positives are  102
# True Negatives are  9462
# False Negatives are  2357
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  5060
# False positives are  96
# True Negatives are  9468
# False Negatives are  2416
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4997
# False positives are  89
# True Negatives are  9475
# False Negatives are  2479
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4938
# False positives are  81
# True Negatives are  9483
# False Negatives are  2538
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4881
# False positives are  69
# True Negatives are  9495
# False Negatives are  2595
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4808
# False positives are  67
# True Negatives are  9497
# False Negatives are  2668
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4735
# False positives are  64
# True Negatives are  9500
# False Negatives are  2741
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4677
# False positives are  61
# True Negatives are  9503
# False Negatives are  2799
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4586
# False positives are  58
# True Negatives are  9506
# False Negatives are  2890
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4500
# False positives are  55
# True Negatives are  9509
# False Negatives are  2976
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4413
# False positives are  53
# True Negatives are  9511
# False Negatives are  3063
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4294
# False positives are  49
# True Negatives are  9515
# False Negatives are  3182
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  4156
# False positives are  42
# True Negatives are  9522
# False Negatives are  3320
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  3987
# False positives are  38
# True Negatives are  9526
# False Negatives are  3489
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  3793
# False positives are  30
# True Negatives are  9534
# False Negatives are  3683
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  3561
# False positives are  25
# True Negatives are  9539
# False Negatives are  3915
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  3245
# False positives are  21
# True Negatives are  9543
# False Negatives are  4231
# [[ 0.00339919]
#  [ 0.00149453]
#  [ 0.00099587]
#  ...
#  [-0.00700599]
#  [-0.22521937]
#  [-0.01014459]]
# True positives are  2735
# False positives are  10
# True Negatives are  9554
# False Negatives are  4741

# %%
dict_val = {'accuracy':accuracy,'TP':TP,'FP':FP,'TN':TN,'FN':FN,'TPR':TPR,'FPR':FPR,'Precision':Precision,'Recall':Recall,'F1_score':F1_score}

# %%
df_val = pd.DataFrame.from_dict(dict_val)

# %%
df_val['ind'] =list_t

# %%
df_val.set_index('ind')
# Out:
#       accuracy         TP         FP         TN         FN       TPR  \
# ind
# 0.05  0.861326  42.024648  12.018779  44.107981   1.848592  0.957865
# 0.10  0.894777  41.068075   7.717136  48.409624   2.805164  0.936062
# 0.15  0.908979  40.363850   5.592723  50.534038   3.509390  0.920011
# 0.20  0.911268  39.600939   4.600939  51.525822   4.272300  0.902622
# 0.25  0.911268  38.896714   3.896714  52.230047   4.976526  0.886570
# 0.30  0.909977  38.251174   3.380282  52.746479   5.622066  0.871857
# 0.35  0.908216  37.611502   2.916667  53.210094   6.261737  0.857277
# 0.40  0.906162  37.007042   2.517606  53.609155   6.866197  0.843499
# 0.45  0.902993  36.349765   2.177230  53.949531   7.523474  0.828518
# 0.50  0.899589  35.780516   1.948357  54.178404   8.092723  0.815543
# 0.55  0.895481  35.158451   1.737089  54.389671   8.714789  0.801364
# 0.60  0.890786  34.436620   1.484742  54.642019   9.436620  0.784912
# 0.65  0.884214  33.573944   1.279343  54.847418  10.299296  0.765249
# 0.70  0.877993  32.787559   1.115023  55.011737  11.085681  0.747325
# 0.75  0.869190  31.725352   0.933099  55.193662  12.147887  0.723114
# 0.80  0.860387  30.575117   0.663146  55.463615  13.298122  0.696897
# 0.81  0.858040  30.305164   0.627934  55.498826  13.568075  0.690744
# 0.82  0.855692  30.041080   0.598592  55.528169  13.832160  0.684724
